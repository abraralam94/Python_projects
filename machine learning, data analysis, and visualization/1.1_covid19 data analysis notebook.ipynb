# %% [markdown]
# # Fundamental Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules loaded.')
# Out:
# Modules loaded.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(['Lat', 'Long'], axis = 1, inplace = True)

# %%
corona_dataset_csv.head(11)
# Out:
#                   Province/State       Country/Region  1/22/20  1/23/20  \
# 0                            NaN          Afghanistan        0        0
# 1                            NaN              Albania        0        0
# 2                            NaN              Algeria        0        0
# 3                            NaN              Andorra        0        0
# 4                            NaN               Angola        0        0
# 5                            NaN  Antigua and Barbuda        0        0
# 6                            NaN            Argentina        0        0
# 7                            NaN              Armenia        0        0
# 8   Australian Capital Territory            Australia        0        0
# 9                New South Wales            Australia        0        0
# 10            Northern Territory            Australia        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc["China"][:3].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc["China"].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries:
    max = corona_dataset_aggregated.loc[country].diff().max()
    max_infection_rates.append(max)
max_infection_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
corona_dataset_aggregated["Max infection rate"] = max_infection_rates
corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
# We remove the specific month and date column entries
corona_data = pd.DataFrame(corona_dataset_aggregated["Max infection rate"])

# %%
corona_data
# Out:
#                     Max infection rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
corona_data.loc["China"]["Max infection rate"]
# Out:
# 15136.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report_csv.head(300)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols, axis = 1, inplace = True)

# %%
happiness_report_csv.head(10)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
# 5       Switzerland           1.452           1.526                    1.052
# 6            Sweden           1.387           1.487                    1.009
# 7       New Zealand           1.303           1.557                    1.026
# 8            Canada           1.365           1.505                    1.039
# 9           Austria           1.376           1.475                    1.016
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# ...

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
happiness_report_csv.set_index("Country or region", inplace = True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
# lets check our corona dataset and its shape
corona_data.head()
# Out:
#                 Max infection rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
# lets check our cleaned happiness report dataset
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### We perform an inner join of both tables since we have matching index conuntry name, and the number of countries are different in both tables

# %%
data = corona_data.join(happiness_report_csv, how = "inner")

# %%
data.head(50)
# Out:
#                           Max infection rate  GDP per capita  Social support  \
# Afghanistan                            232.0           0.350           0.517
# Albania                                 34.0           0.947           0.848
# Algeria                                199.0           1.002           1.160
# Argentina                              291.0           1.092           1.432
# Armenia                                134.0           0.850           1.055
# Australia                              497.0           1.372           1.548
# Austria                               1321.0           1.376           1.475
# Azerbaijan                             105.0           1.043           1.147
# Bahrain                                301.0           1.362           1.368
# Bangladesh                             641.0           0.562           0.928
# Belarus                               1485.0           1.067           1.465
# ...

# %%
data.loc["China"]["Max infection rate"]
# Out:
# 15136.0

# %% [markdown]
# ##### The result above varifies that our join was indeed inner

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               Max infection rate  GDP per capita  \
# Max infection rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max infection rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max infection rate                                0.078196
# ...

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %% [markdown]
# ### Task 5.1: Plotting max infection rate vs GDP per capita

# %%
x = data["GDP per capita"]

# %%
y = data["Max infection rate"]

# %%
sns.scatterplot(x, y)

# %% [markdown]
# ##### The plot above does not give any clear picture. However,before dismissing any correlation, we opt for taking the log of Max infection rate, since our scaling is drastically different for x and y axis

# %%
sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x, np.log(y))

# %% [markdown]
# ##### The plot above now depicts a clearer picture of a positive correlation. This does not necessarily mean however that one causes the other

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x1, y1 = data['Social support'], data['Max infection rate']

# %%
sns.regplot(x1,np.log(y1))

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x2, y2 = data['Healthy life expectancy'], data['Max infection rate']

# %%
sns.regplot(x2,np.log(y2))

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x3, y3 = data['Freedom to make life choices'], data['Max infection rate']

# %%
sns.regplot(x3,np.log(y3))

# %% [markdown]
# ##### The regplot of Max infection rate vs Freedom to make life choices however depicts a much weaker correlation
