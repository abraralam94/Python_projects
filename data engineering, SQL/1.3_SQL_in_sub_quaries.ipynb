# %% [markdown]
# ### This project deals with sub-queries and multiple tables(Cartesian join)

# %%
import ibm_db
import ibm_db_sa
import sqlalchemy

# %%
# %load_ext sql

# %%
# connecting to our db2 database (contains private info.)
# %sql ibm_db_sa://pnp67536:--------------@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB

# %% [markdown]
# please note that we are accessing EMPLOYEES table, and DEPARTMENTS from an IBM DB2 database

# %%
# %%sql
# select * from EMPLOYEES;
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('E1001    ', 'John', 'Thomas', '123456   ', datetime.date(1976, 1, 9), 'M', '5631 Rice, OakPark,IL', '100      ', Decimal('100000.00'), '30001    ', '2        '),
#  ('E1002    ', 'Alice', 'James', '123457   ', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200      ', Decimal('80000.00'), '30002    ', '5        '),
#  ('E1003    ', 'Steve', 'Wells', '123458   ', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300      ', Decimal('50000.00'), '30002    ', '5        '),
#  ('E1004    ', 'Santosh', 'Kumar', '123459   ', datetime.date(1985, 7, 20), 'M', '511 Aurora Av, Aurora,IL', '400      ', Decimal('60000.00'), '30004    ', '5        '),
#  ('E1005    ', 'Ahmed', 'Hussain', '123410   ', datetime.date(1981, 1, 4), 'M', '216 Oak Tree, Geneva,IL', '500      ', Decimal('70000.00'), '30001    ', '2        '),
# ...

# %%
# %%sql
# select * from departments
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('2        ', 'Architect Group', '30001    ', 'L0001    '),
#  ('5        ', 'Software Group', '30002    ', 'L0002    '),
#  ('7        ', 'Design Team', '30003    ', 'L0003    ')]

# %% [markdown]
# ##### we want to retrieve the list of employees who earn more than the average salary

# %%
# %%sql
# SELECT F_NAME, L_NAME FROM EMPLOYEES
# WHERE SALARY > (SELECT AVG(SALARY) FROM EMPLOYEES);
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('John', 'Thomas'), ('Alice', 'James'), ('Nancy', 'Allen')]

# %% [markdown]
# ##### If we want to retrieve only the employee records from the employees table for which a department ID exists in the departments table,we can use a sub-query as follows.

# %%
# %%sql
# SELECT * FROM EMPLOYEES
# WHERE DEP_ID IN
# (SELECT DEPT_ID_DEP FROM DEPARTMENTS);
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('E1001    ', 'John', 'Thomas', '123456   ', datetime.date(1976, 1, 9), 'M', '5631 Rice, OakPark,IL', '100      ', Decimal('100000.00'), '30001    ', '2        '),
#  ('E1002    ', 'Alice', 'James', '123457   ', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200      ', Decimal('80000.00'), '30002    ', '5        '),
#  ('E1003    ', 'Steve', 'Wells', '123458   ', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300      ', Decimal('50000.00'), '30002    ', '5        '),
#  ('E1004    ', 'Santosh', 'Kumar', '123459   ', datetime.date(1985, 7, 20), 'M', '511 Aurora Av, Aurora,IL', '400      ', Decimal('60000.00'), '30004    ', '5        '),
#  ('E1005    ', 'Ahmed', 'Hussain', '123410   ', datetime.date(1981, 1, 4), 'M', '216 Oak Tree, Geneva,IL', '500      ', Decimal('70000.00'), '30001    ', '2        '),
# ...

# %% [markdown]
# ##### Let's say we want to retrieve only the list of employees from a specific location of L0002. We do not have any location information in the employees table, but the departments table has a column called location ID. Therefore, we can use a sub-query from the Departments table as input to the employee table query as follows

# %%
# %%sql
# SELECT * FROM EMPLOYEES
# WHERE DEP_ID IN
# (SELECT DEPT_ID_DEP FROM DEPARTMENTS
# WHERE LOC_ID = 'L0002');
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('E1002    ', 'Alice', 'James', '123457   ', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200      ', Decimal('80000.00'), '30002    ', '5        '),
#  ('E1003    ', 'Steve', 'Wells', '123458   ', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300      ', Decimal('50000.00'), '30002    ', '5        '),
#  ('E1004    ', 'Santosh', 'Kumar', '123459   ', datetime.date(1985, 7, 20), 'M', '511 Aurora Av, Aurora,IL', '400      ', Decimal('60000.00'), '30004    ', '5        '),
#  ('E1010    ', 'Ann', 'Jacob', '123415   ', datetime.date(1982, 3, 30), 'F', '111 Britany Springs,Elgin,IL', '220      ', Decimal('70000.00'), '30004    ', '5        ')]

# %% [markdown]
# ##### let's retrieve the department ID and department name for employees who earn more than $70,000.

# %%
# %%sql
# SELECT DEPT_ID_DEP, DEP_NAME FROM DEPARTMENTS
# WHERE DEPT_ID_DEP IN
# (SELECT DEP_ID FROM EMPLOYEES
# WHERE SALARY  > 70000);
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('2        ', 'Architect Group'), ('5        ', 'Software Group')]

# %% [markdown]
# ##### Here we specify two tables in the FROM clause. This results in a implicit table join

# %%
# %%sql
# SELECT * FROM EMPLOYEES, DEPARTMENTS LIMIT 10;
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('E1001    ', 'John', 'Thomas', '123456   ', datetime.date(1976, 1, 9), 'M', '5631 Rice, OakPark,IL', '100      ', Decimal('100000.00'), '30001    ', '2        ', '2        ', 'Architect Group', '30001    ', 'L0001    '),
#  ('E1002    ', 'Alice', 'James', '123457   ', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200      ', Decimal('80000.00'), '30002    ', '5        ', '2        ', 'Architect Group', '30001    ', 'L0001    '),
#  ('E1003    ', 'Steve', 'Wells', '123458   ', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300      ', Decimal('50000.00'), '30002    ', '5        ', '2        ', 'Architect Group', '30001    ', 'L0001    '),
# ...

# %% [markdown]
# ##### Let's look at an example where we limit the result set to only rows with matching department IDs.

# %%
# %%sql
# SELECT * FROM EMPLOYEES, DEPARTMENTS
# WHERE EMPLOYEES.DEP_ID = DEPARTMENTS.DEPT_ID_DEP;
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('E1001    ', 'John', 'Thomas', '123456   ', datetime.date(1976, 1, 9), 'M', '5631 Rice, OakPark,IL', '100      ', Decimal('100000.00'), '30001    ', '2        ', '2        ', 'Architect Group', '30001    ', 'L0001    '),
#  ('E1002    ', 'Alice', 'James', '123457   ', datetime.date(1972, 7, 31), 'F', '980 Berry ln, Elgin,IL', '200      ', Decimal('80000.00'), '30002    ', '5        ', '5        ', 'Software Group', '30002    ', 'L0002    '),
#  ('E1003    ', 'Steve', 'Wells', '123458   ', datetime.date(1980, 8, 10), 'M', '291 Springs, Gary,IL', '300      ', Decimal('50000.00'), '30002    ', '5        ', '5        ', 'Software Group', '30002    ', 'L0002    '),
# ...

# %% [markdown]
# ##### If we wanted to see the department name for each employee, we would enter the code as follows:

# %%
# %%sql
# SELECT EMPLOYEES.F_NAME, EMPLOYEES.L_NAME, DEPARTMENTS.DEP_NAME
# FROM EMPLOYEES, DEPARTMENTS
# WHERE EMPLOYEES.DEP_ID = DEPARTMENTS.DEPT_ID_DEP
# Out:
#  * ibm_db_sa://pnp67536:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('John', 'Thomas', 'Architect Group'),
#  ('Alice', 'James', 'Software Group'),
#  ('Steve', 'Wells', 'Software Group'),
#  ('Santosh', 'Kumar', 'Software Group'),
#  ('Ahmed', 'Hussain', 'Architect Group'),
#  ('Nancy', 'Allen', 'Architect Group'),
#  ('Mary', 'Thomas', 'Design Team'),
#  ('Bharath', 'Gupta', 'Design Team'),
#  ('Andrea', 'Jones', 'Design Team'),
#  ('Ann', 'Jacob', 'Software Group')]
